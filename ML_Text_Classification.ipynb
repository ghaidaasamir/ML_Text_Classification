# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score
import joblib
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.model_selection import train_test_split

nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('overview-of-recordings.csv')
df_text = df[['phrase', 'prompt']]

# %%
df_text
# Out:
#                                                  phrase            prompt
# 0                       When I remember her I feel down    Emotional pain
# 1     When I carry heavy things I feel like breaking...  Hair falling out
# 2             there is too much pain when i move my arm       Heart hurts
# 3     My son had his lip pierced and it is swollen a...    Infected wound
# 4                My muscles in my lower back are aching    Infected wound
# ...                                                 ...               ...
# 6656  I feel a burning sensation in my guts about 2 ...      Stomach ache
# 6657     I have a split on my thumb that will not heal.        Open wound
# 6658                I feel a lot of pain in the joints.        Joint pain
# 6659        The area around my heart doesn't feel good.       Heart hurts
# 6660                  I complain alot with skin allergy        Skin issue
#
# [6661 rows x 2 columns]

# %%
df_text["prompt"].unique()
# Out:
# array(['Emotional pain', 'Hair falling out', 'Heart hurts',
#        'Infected wound', 'Foot ache', 'Shoulder pain',
#        'Injury from sports', 'Skin issue', 'Stomach ache', 'Knee pain',
#        'Joint pain', 'Hard to breath', 'Head ache', 'Body feels weak',
#        'Feeling dizzy', 'Back pain', 'Open wound', 'Internal pain',
#        'Blurry vision', 'Acne', 'Muscle pain', 'Neck pain', 'Cough',
#        'Ear ache', 'Feeling cold'], dtype=object)

# %%
df_text["prompt"].value_counts()
# Out:
# prompt
# Acne                  328
# Shoulder pain         320
# Joint pain            318
# Infected wound        306
# Knee pain             305
# Cough                 293
# Feeling dizzy         283
# Muscle pain           282
# Heart hurts           273
# Ear ache              270
# Hair falling out      264
# Feeling cold          263
# Head ache             263
# Skin issue            262
# Stomach ache          261
# Back pain             259
# Neck pain             251
# Internal pain         248
# Blurry vision         246
# Body feels weak       241
# Hard to breath        233
# Emotional pain        231
# Injury from sports    230
# Foot ache             223
# Open wound            208
# Name: count, dtype: int64

# %%
# training (80%) and temp (20%)
train_df, temp_df = train_test_split(df_text, test_size=0.2, random_state=42)

# validation and test (each 10%)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

print("Train shape:", train_df.shape)
print("Validation shape:", val_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (5328, 2)
# Validation shape: (666, 2)
# Test shape: (667, 2)

# %%
train_df
# Out:
#                                                  phrase          prompt
# 3497                       I have acne all over my face            Acne
# 418   i have a problem in seeing objects it is too d...   Blurry vision
# 3306                      i cant sleep because of cough           Cough
# 5510      I have a very rash sensation close to my arms      Skin issue
# 6656  I feel a burning sensation in my guts about 2 ...    Stomach ache
# ...                                                 ...             ...
# 3772  I can't carry anything I have a pain in my sho...   Shoulder pain
# 5191                         There is an injured person  Infected wound
# 5226  I have acne in my face and other problema in m...      Skin issue
# 5390                     I have a sharp pain in my neck       Neck pain
# 860                         My shoulder has agreat pain   Shoulder pain
#
# [5328 rows x 2 columns]

# %%
test_df
# Out:
#                                                  phrase          prompt
# 4043                   I feel like my heart is on fire.     Heart hurts
# 420                               I feel abdominal pain    Stomach ache
# 5803                       I think my wound is infected  Infected wound
# 334                      I feel a tightness in my chest  Hard to breath
# 1545                 I do not feel better in my muscles     Muscle pain
# ...                                                 ...             ...
# 2881         I can't work good I have a pain in my knee       Knee pain
# 4030                       I have acne all over my face            Acne
# 2210  I wake up with a stiff neck every morning.  Ma...       Neck pain
# 6133                 I do not feel better in my muscles     Muscle pain
# 6445  I feel cold and chills even though my clothes ...    Feeling cold
#
# [667 rows x 2 columns]

# %%
def preprocess(text):
    doc = nlp(text.lower().strip())
    tokens = []
    for token in doc:
        if token.text in STOP_WORDS:
            continue
        if token.is_punct:
            continue
        tokens.append(token.lemma_)
    return " ".join(tokens)

# preprocessing
train_df['clean_phrase'] = train_df['phrase'].apply(preprocess)
val_df['clean_phrase'] = val_df['phrase'].apply(preprocess)
test_df['clean_phrase'] = test_df['phrase'].apply(preprocess)

# Feature Engineering
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2),
    stop_words='english',
    sublinear_tf=True
)

X_train = tfidf.fit_transform(train_df['clean_phrase'])
X_val = tfidf.transform(val_df['clean_phrase'])
X_test = tfidf.transform(test_df['clean_phrase'])

# Encode labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['prompt'])
y_val = label_encoder.transform(val_df['prompt'])
y_test = label_encoder.transform(test_df['prompt'])

# Model 
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, class_weight='balanced'),
    "Random Forest": RandomForestClassifier(n_estimators=200),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
}

best_model = None
best_score = 0

for name, model in models.items():
    model.fit(X_train, y_train)
    val_preds = model.predict(X_val)
    acc = accuracy_score(y_val, val_preds)
    f1 = f1_score(y_val, val_preds, average='weighted')
    print(f"{name}:")
    print(f"  Validation Accuracy: {acc:.3f}")
    print(f"  Validation F1-Score: {f1:.3f}")
    
    if f1 > best_score:
        best_score = f1
        best_model = model

# evaluate on test set
test_preds = best_model.predict(X_test)
print("Test Performance:")
print(f"Accuracy: {accuracy_score(y_test, test_preds):.3f}")
print(f"F1-Score: {f1_score(y_test, test_preds, average='weighted'):.3f}")

# Save pipeline
joblib.dump({
    'tfidf': tfidf,
    'model': best_model,
    'label_encoder': label_encoder
}, "traditional_ml_pipeline.pkl")
# Out:
# Logistic Regression:
#   Validation Accuracy: 0.988
#   Validation F1-Score: 0.988
# Random Forest:
#   Validation Accuracy: 0.995
#   Validation F1-Score: 0.995
# /home/ghaidaa/anaconda3/envs/tf_env_v2/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:16:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost:
#   Validation Accuracy: 0.995
#   Validation F1-Score: 0.995
#
# Test Performance:
# Accuracy: 0.997
# F1-Score: 0.997
# ['traditional_ml_pipeline.pkl']

# %%
decoded_preds = label_encoder.inverse_transform(test_preds)
decoded_preds
# Out:
# array(['Heart hurts', 'Stomach ache', 'Infected wound', 'Hard to breath',
#        'Muscle pain', 'Feeling cold', 'Emotional pain', 'Internal pain',
#        'Hard to breath', 'Feeling cold', 'Hard to breath',
#        'Hair falling out', 'Heart hurts', 'Heart hurts', 'Stomach ache',
#        'Shoulder pain', 'Skin issue', 'Emotional pain', 'Blurry vision',
#        'Feeling dizzy', 'Body feels weak', 'Shoulder pain',
#        'Feeling dizzy', 'Feeling dizzy', 'Blurry vision', 'Knee pain',
#        'Acne', 'Cough', 'Skin issue', 'Blurry vision', 'Open wound',
#        'Skin issue', 'Foot ache', 'Open wound', 'Body feels weak',
#        'Internal pain', 'Muscle pain', 'Body feels weak', 'Feeling cold',
#        'Knee pain', 'Acne', 'Skin issue', 'Neck pain', 'Emotional pain',
#        'Neck pain', 'Stomach ache', 'Open wound', 'Shoulder pain',
#        'Injury from sports', 'Hard to breath', 'Injury from sports',
#        'Hair falling out', 'Joint pain', 'Knee pain', 'Hard to breath',
#        'Cough', 'Head ache', 'Hair falling out', 'Injury from sports',
#        'Infected wound', 'Body feels weak', 'Infected wound', 'Foot ache',
#        'Stomach ache', 'Emotional pain', 'Open wound', 'Heart hurts',
#        'Foot ache', 'Skin issue', 'Feeling cold', 'Head ache',
#        'Joint pain', 'Infected wound', 'Body feels weak', 'Knee pain',
#        'Skin issue', 'Back pain', 'Infected wound', 'Neck pain',
#        'Stomach ache', 'Cough', 'Knee pain', 'Hard to breath',
#        'Foot ache', 'Hard to breath', 'Infected wound', 'Knee pain',
#        'Ear ache', 'Open wound', 'Muscle pain', 'Body feels weak',
#        'Emotional pain', 'Muscle pain', 'Blurry vision', 'Back pain',
#        'Body feels weak', 'Muscle pain', 'Injury from sports',
#        'Body feels weak', 'Muscle pain', 'Open wound', 'Joint pain',
#        'Hair falling out', 'Hard to breath', 'Hair falling out',
#        'Ear ache', 'Emotional pain', 'Feeling cold', 'Back pain',
#        'Muscle pain', 'Body feels weak', 'Head ache', 'Hard to breath',
#        'Open wound', 'Knee pain', 'Shoulder pain', 'Back pain',
#        'Foot ache', 'Feeling cold', 'Body feels weak', 'Heart hurts',
#        'Muscle pain', 'Skin issue', 'Feeling cold', 'Ear ache',
#        'Neck pain', 'Heart hurts', 'Foot ache', 'Head ache', 'Open wound',
#        'Injury from sports', 'Stomach ache', 'Feeling dizzy',
#        'Heart hurts', 'Feeling dizzy', 'Cough', 'Shoulder pain',
#        'Muscle pain', 'Foot ache', 'Neck pain', 'Feeling dizzy',
#        'Stomach ache', 'Injury from sports', 'Feeling cold', 'Back pain',
#        'Neck pain', 'Internal pain', 'Ear ache', 'Injury from sports',
#        'Emotional pain', 'Cough', 'Cough', 'Head ache', 'Back pain',
#        'Open wound', 'Shoulder pain', 'Heart hurts', 'Open wound',
#        'Ear ache', 'Cough', 'Feeling cold', 'Neck pain', 'Neck pain',
#        'Internal pain', 'Feeling dizzy', 'Emotional pain', 'Knee pain',
#        'Infected wound', 'Hard to breath', 'Stomach ache',
#        'Hair falling out', 'Muscle pain', 'Back pain', 'Head ache',
#        'Heart hurts', 'Knee pain', 'Stomach ache', 'Infected wound',
#        'Infected wound', 'Foot ache', 'Skin issue', 'Head ache',
#        'Heart hurts', 'Head ache', 'Knee pain', 'Neck pain', 'Ear ache',
#        'Joint pain', 'Feeling dizzy', 'Joint pain', 'Back pain',
#        'Muscle pain', 'Back pain', 'Internal pain', 'Infected wound',
#        'Knee pain', 'Foot ache', 'Infected wound', 'Joint pain',
#        'Knee pain', 'Foot ache', 'Emotional pain', 'Hard to breath',
#        'Body feels weak', 'Acne', 'Knee pain', 'Blurry vision',
#        'Infected wound', 'Infected wound', 'Feeling cold', 'Muscle pain',
#        'Cough', 'Injury from sports', 'Back pain', 'Feeling dizzy',
#        'Shoulder pain', 'Ear ache', 'Joint pain', 'Injury from sports',
#        'Feeling dizzy', 'Open wound', 'Stomach ache', 'Hair falling out',
#        'Hair falling out', 'Feeling cold', 'Skin issue', 'Joint pain',
#        'Injury from sports', 'Internal pain', 'Injury from sports',
#        'Foot ache', 'Stomach ache', 'Skin issue', 'Shoulder pain',
#        'Stomach ache', 'Open wound', 'Back pain', 'Skin issue',
#        'Blurry vision', 'Knee pain', 'Feeling dizzy', 'Infected wound',
#        'Heart hurts', 'Acne', 'Body feels weak', 'Muscle pain',
#        'Hard to breath', 'Head ache', 'Feeling cold', 'Feeling cold',
#        'Shoulder pain', 'Acne', 'Acne', 'Feeling dizzy',
#        'Hair falling out', 'Knee pain', 'Skin issue', 'Hair falling out',
#        'Hard to breath', 'Head ache', 'Head ache', 'Neck pain',
#        'Feeling dizzy', 'Acne', 'Hard to breath', 'Hard to breath',
#        'Joint pain', 'Stomach ache', 'Ear ache', 'Ear ache',
#        'Shoulder pain', 'Head ache', 'Injury from sports', 'Knee pain',
#        'Neck pain', 'Stomach ache', 'Head ache', 'Heart hurts',
#        'Skin issue', 'Heart hurts', 'Internal pain', 'Emotional pain',
#        'Joint pain', 'Back pain', 'Hair falling out', 'Emotional pain',
#        'Knee pain', 'Stomach ache', 'Hard to breath', 'Acne',
#        'Blurry vision', 'Stomach ache', 'Knee pain', 'Shoulder pain',
#        'Joint pain', 'Heart hurts', 'Shoulder pain', 'Shoulder pain',
#        'Back pain', 'Blurry vision', 'Infected wound', 'Open wound',
#        'Injury from sports', 'Foot ache', 'Skin issue', 'Knee pain',
#        'Body feels weak', 'Joint pain', 'Ear ache', 'Muscle pain',
#        'Infected wound', 'Blurry vision', 'Acne', 'Back pain', 'Acne',
#        'Joint pain', 'Shoulder pain', 'Back pain', 'Cough', 'Head ache',
#        'Knee pain', 'Neck pain', 'Hard to breath', 'Injury from sports',
#        'Back pain', 'Shoulder pain', 'Hair falling out',
#        'Hair falling out', 'Muscle pain', 'Feeling cold', 'Heart hurts',
#        'Knee pain', 'Infected wound', 'Body feels weak',
#        'Body feels weak', 'Foot ache', 'Infected wound', 'Back pain',
#        'Open wound', 'Injury from sports', 'Internal pain', 'Heart hurts',
#        'Injury from sports', 'Back pain', 'Neck pain', 'Neck pain',
#        'Muscle pain', 'Muscle pain', 'Blurry vision', 'Head ache',
#        'Knee pain', 'Body feels weak', 'Acne', 'Joint pain',
#        'Emotional pain', 'Internal pain', 'Head ache', 'Hair falling out',
#        'Injury from sports', 'Joint pain', 'Back pain',
#        'Injury from sports', 'Muscle pain', 'Back pain', 'Skin issue',
#        'Knee pain', 'Joint pain', 'Ear ache', 'Hair falling out',
#        'Stomach ache', 'Joint pain', 'Knee pain', 'Emotional pain',
#        'Hard to breath', 'Emotional pain', 'Hair falling out',
#        'Emotional pain', 'Hard to breath', 'Foot ache', 'Hard to breath',
#        'Feeling dizzy', 'Knee pain', 'Shoulder pain', 'Body feels weak',
#        'Joint pain', 'Blurry vision', 'Hard to breath',
#        'Injury from sports', 'Neck pain', 'Cough', 'Shoulder pain',
#        'Stomach ache', 'Injury from sports', 'Muscle pain',
#        'Stomach ache', 'Back pain', 'Muscle pain', 'Knee pain',
#        'Stomach ache', 'Internal pain', 'Emotional pain', 'Cough',
#        'Hair falling out', 'Stomach ache', 'Ear ache', 'Heart hurts',
#        'Blurry vision', 'Hair falling out', 'Ear ache', 'Joint pain',
#        'Internal pain', 'Cough', 'Hard to breath', 'Body feels weak',
#        'Blurry vision', 'Joint pain', 'Cough', 'Injury from sports',
#        'Shoulder pain', 'Muscle pain', 'Heart hurts', 'Muscle pain',
#        'Feeling dizzy', 'Hard to breath', 'Hair falling out', 'Head ache',
#        'Acne', 'Body feels weak', 'Hair falling out', 'Hard to breath',
#        'Feeling cold', 'Hard to breath', 'Joint pain', 'Muscle pain',
#        'Emotional pain', 'Joint pain', 'Cough', 'Foot ache',
#        'Feeling cold', 'Acne', 'Back pain', 'Stomach ache', 'Open wound',
#        'Internal pain', 'Stomach ache', 'Shoulder pain', 'Infected wound',
#        'Blurry vision', 'Cough', 'Foot ache', 'Cough', 'Cough',
#        'Skin issue', 'Skin issue', 'Stomach ache', 'Hair falling out',
#        'Internal pain', 'Skin issue', 'Blurry vision', 'Feeling cold',
#        'Joint pain', 'Knee pain', 'Shoulder pain', 'Joint pain',
#        'Stomach ache', 'Neck pain', 'Head ache', 'Blurry vision', 'Cough',
#        'Emotional pain', 'Muscle pain', 'Muscle pain', 'Body feels weak',
#        'Body feels weak', 'Knee pain', 'Blurry vision', 'Internal pain',
#        'Back pain', 'Blurry vision', 'Heart hurts', 'Infected wound',
#        'Joint pain', 'Internal pain', 'Body feels weak', 'Joint pain',
#        'Ear ache', 'Internal pain', 'Foot ache', 'Cough', 'Stomach ache',
#        'Joint pain', 'Heart hurts', 'Blurry vision', 'Stomach ache',
#        'Hair falling out', 'Knee pain', 'Muscle pain', 'Hair falling out',
#        'Hard to breath', 'Open wound', 'Back pain', 'Skin issue',
#        'Knee pain', 'Body feels weak', 'Body feels weak',
#        'Infected wound', 'Acne', 'Knee pain', 'Knee pain',
#        'Hard to breath', 'Hard to breath', 'Blurry vision', 'Heart hurts',
#        'Shoulder pain', 'Head ache', 'Infected wound', 'Infected wound',
#        'Neck pain', 'Body feels weak', 'Emotional pain', 'Cough',
#        'Infected wound', 'Skin issue', 'Cough', 'Heart hurts',
#        'Injury from sports', 'Hair falling out', 'Feeling dizzy',
#        'Infected wound', 'Joint pain', 'Head ache', 'Injury from sports',
#        'Stomach ache', 'Emotional pain', 'Emotional pain', 'Heart hurts',
#        'Shoulder pain', 'Body feels weak', 'Knee pain', 'Shoulder pain',
#        'Muscle pain', 'Shoulder pain', 'Muscle pain', 'Stomach ache',
#        'Hair falling out', 'Neck pain', 'Hair falling out', 'Heart hurts',
#        'Internal pain', 'Back pain', 'Muscle pain', 'Body feels weak',
#        'Infected wound', 'Body feels weak', 'Cough', 'Blurry vision',
#        'Cough', 'Heart hurts', 'Neck pain', 'Body feels weak',
#        'Heart hurts', 'Blurry vision', 'Feeling dizzy', 'Stomach ache',
#        'Injury from sports', 'Muscle pain', 'Stomach ache', 'Open wound',
#        'Blurry vision', 'Back pain', 'Knee pain', 'Foot ache',
#        'Body feels weak', 'Heart hurts', 'Knee pain', 'Hair falling out',
#        'Back pain', 'Stomach ache', 'Emotional pain', 'Emotional pain',
#        'Acne', 'Cough', 'Internal pain', 'Stomach ache', 'Foot ache',
#        'Heart hurts', 'Neck pain', 'Infected wound', 'Open wound',
#        'Head ache', 'Infected wound', 'Stomach ache', 'Ear ache',
#        'Heart hurts', 'Blurry vision', 'Cough', 'Back pain',
#        'Heart hurts', 'Feeling cold', 'Blurry vision', 'Joint pain',
#        'Injury from sports', 'Stomach ache', 'Body feels weak',
#        'Ear ache', 'Ear ache', 'Internal pain', 'Open wound', 'Foot ache',
#        'Internal pain', 'Feeling cold', 'Cough', 'Blurry vision',
#        'Neck pain', 'Acne', 'Stomach ache', 'Infected wound', 'Cough',
#        'Muscle pain', 'Feeling dizzy', 'Ear ache', 'Body feels weak',
#        'Infected wound', 'Skin issue', 'Body feels weak', 'Foot ache',
#        'Cough', 'Shoulder pain', 'Blurry vision', 'Joint pain',
#        'Joint pain', 'Foot ache', 'Body feels weak', 'Acne',
#        'Hard to breath', 'Muscle pain', 'Cough', 'Body feels weak',
#        'Heart hurts', 'Blurry vision', 'Injury from sports',
#        'Shoulder pain', 'Open wound', 'Infected wound', 'Knee pain',
#        'Head ache', 'Body feels weak', 'Hard to breath', 'Feeling cold',
#        'Skin issue', 'Stomach ache', 'Injury from sports', 'Neck pain',
#        'Acne', 'Ear ache', 'Acne', 'Joint pain', 'Infected wound',
#        'Stomach ache', 'Muscle pain', 'Stomach ache', 'Knee pain',
#        'Knee pain', 'Acne', 'Neck pain', 'Muscle pain', 'Feeling cold'],
#       dtype=object)

# %%
for test_i, pred in zip(test_df['clean_phrase'],decoded_preds):
    print(test_i," : ",pred)
# Out:
# feel like heart fire  :  Heart hurts
# feel abdominal pain  :  Stomach ache
# think wound infect  :  Infected wound
# feel tightness chest  :  Hard to breath
# feel well muscle  :  Muscle pain
# chill ache  :  Feeling cold
# grand father die feel hard emotional pain  :  Emotional pain
# head pain single day  :  Internal pain
# feel like squeeze lung  :  Hard to breath
# cold wear layer  :  Feeling cold
# feel great pressure chest  :  Hard to breath
# shower drain hair time  :  Hair falling out
# heart beat fast scare  :  Heart hurts
# heart hurt sad  :  Heart hurts
# feel nauseous  :  Stomach ache
# feel like go acupuncture practice 100 needle shoulder  :  Shoulder pain
# dark arm  :  Skin issue
# feel pain think  :  Emotional pain
# have hard time read letter fuzzy  :  Blurry vision
# awake morning feel strange vertigo  :  Feeling dizzy
# feel weak body  :  Body feels weak
# throb shoulder  :  Shoulder pain
# feel dizzy sight  :  Feeling dizzy
# stand feel dizzy know  :  Feeling dizzy
# blurry vision wrong medicine  :  Blurry vision
# shoot pain kneecap work  :  Knee pain
# acne embarasse read  :  Acne
